# %%
import requests
import time

url = 'https://www.infraweb-rws.fi/api/auth/login'
headers = {
    'Content-Type': 'application/json',
    'Accept': 'application/json'
}
payload = {
    "username": "",
    "password": ""
}

response = requests.post(url, headers=headers, json=payload)

print(response.status_code)
print(response.json())

token = response.json()['token']

req_headers = {"Authorization": f"Bearer {token}"}
# Out:
# 200
# {'token': 'eyJhbGciOiJIUzUxMiJ9.....ri0GUb3NAQkKZcZGY-26gYaw1Ib5hyHWXMrrV4TUQ1phUkbIGHZ69vi2Psa85uTPUWdwYtTbHvZxRqLX8BhnUg', 'refreshToken': 'eyJhbGciOiJIUzUxMiJ9..7Ai0jae6Xp17MyjW0VVtEJ8PtRPCHbCBWmF0ovhlH7ndE_fdQ_SSXlF_wbrPbsvirqbsDbSkqq2KHoAlW46g9g'}

# %%
# get permissions

url = 'http://www.infraweb-rws.fi/api/permissions/allowedPermissions'
response = requests.get(url, headers=req_headers)

data = response.json()

# %%
data['userPermissions']['groupPermissions']
# Out:
# {'2309c200-f01b-11ef-b139-295490bf863f': {'entityType': 'DEVICE',
#   'operations': ['READ_CREDENTIALS',
#    'READ_TELEMETRY',
#    'READ_ATTRIBUTES',
#    'READ']},
#  '3a98fa50-eb4c-11ee-889d-fbb72df75e3e': {'entityType': 'ENTITY_VIEW',
#   'operations': ['READ_CREDENTIALS',
#    'READ_TELEMETRY',
#    'READ_ATTRIBUTES',
#    'READ']},
#  '3ca1bee0-f70e-11ee-8e4e-3335ad756794': {'entityType': 'DEVICE',
#   'operations': ['READ_CREDENTIALS',
#    'READ_TELEMETRY',
#    'READ_ATTRIBUTES',
#    'READ']},
#  '1d527fd0-eab9-11ef-8c97-effd2914f551': {'entityType': 'DASHBOARD',
#   'operations': ['READ_CREDENTIALS',
#    'READ_TELEMETRY',
#    'READ_ATTRIBUTES',
#    'READ']}}

# %%
device_groups = [id for id in data['userPermissions']['groupPermissions'] if data['userPermissions']['groupPermissions'][id]['entityType'] == 'DEVICE']
device_groups
# Out:
# ['2309c200-f01b-11ef-b139-295490bf863f',
#  '3ca1bee0-f70e-11ee-8e4e-3335ad756794']

# %%
req_url = "http://www.infraweb-rws.fi/api/entityGroup/2309c200-f01b-11ef-b139-295490bf863f/devices?pageSize=100&page=0"

response = requests.get(req_url, headers=req_headers)

data = response.json()

# %%
data['data']
# Out:
# [{'id': {'entityType': 'DEVICE', 'id': '16ceea10-f562-11e9-8fc0-a3372986e528'},
#   'createdTime': 1571813724977,
#   'tenantId': {'entityType': 'TENANT',
#    'id': '82737eb0-e429-11e9-ac8f-fdcdec2c26a2'},
#   'customerId': {'entityType': 'CUSTOMER',
#    'id': '13814000-1dd2-11b2-8080-808080808080'},
#   'name': 'Tie 9 Jyväskylä - ID9014',
#   'type': 'DigitrafficWeatherStation',
#   'label': None,
#   'deviceProfileId': {'entityType': 'DEVICE_PROFILE',
#    'id': 'b0021190-51b8-11eb-9a0e-f36c5aeb7b48'},
#   'firmwareId': None,
#   'softwareId': None,
#   'externalId': None,
#   'additionalInfo': None,
#   'ownerId': {'entityType': 'TENANT',
#    'id': '82737eb0-e429-11e9-ac8f-fdcdec2c26a2'},
#   'deviceData': {'configuration': {'type': 'DEFAULT'},
#    'transportConfiguration': {'type': 'DEFAULT'}}},
#  {'id': {'entityType': 'DEVICE', 'id': '61726350-9567-11ed-b515-dfe8dba414e9'},
#   'createdTime': 1673850676741,
#   'tenantId': {'entityType': 'TENANT',
#    'id': '82737eb0-e429-11e9-ac8f-fdcdec2c26a2'},
#   'customerId': {'entityType': 'CUSTOMER',
#    'id': '13814000-1dd2-11b2-8080-808080808080'},
#   'name': 'JKL - Starbit - Salontaipaleentie',
#   'type': 'starbit',
#   'label': 'Asennettu Jyväskylään 3/2024',
#   'deviceProfileId': {'entityType': 'DEVICE_PROFILE',
#    'id': '53a70be0-9567-11ed-b515-dfe8dba414e9'},
#   'firmwareId': None,
#   'softwareId': None,
#   'externalId': None,
#   'additionalInfo': {'gateway': False,
#    'overwriteActivityTime': False,
#    'description': ''},
#   'ownerId': {'entityType': 'TENANT',
#    'id': '82737eb0-e429-11e9-ac8f-fdcdec2c26a2'},
#   'deviceData': {'configuration': {'type': 'DEFAULT'},
#    'transportConfiguration': {'type': 'DEFAULT'}}},
#  {'id': {'entityType': 'DEVICE', 'id': '82f04410-e8f0-11e9-ac8f-fdcdec2c26a2'},
#   'createdTime': 1570445529809,
#   'tenantId': {'entityType': 'TENANT',
#    'id': '82737eb0-e429-11e9-ac8f-fdcdec2c26a2'},
#   'customerId': {'entityType': 'CUSTOMER',
#    'id': '13814000-1dd2-11b2-8080-808080808080'},
#   'name': 'WS100 - Tuulimyllyntie',
#   'type': 'WS100',
#   'label': None,
#   'deviceProfileId': {'entityType': 'DEVICE_PROFILE',
#    'id': 'b01bdb20-51b8-11eb-9a0e-f36c5aeb7b48'},
#   'firmwareId': None,
#   'softwareId': None,
#   'externalId': None,
#   'additionalInfo': None,
#   'ownerId': {'entityType': 'TENANT',
#    'id': '82737eb0-e429-11e9-ac8f-fdcdec2c26a2'},
#   'deviceData': {'configuration': {'type': 'DEFAULT'},
#    'transportConfiguration': {'type': 'DEFAULT'}}},
#  {'id': {'entityType': 'DEVICE', 'id': '9ae463e0-8494-11ef-ad64-d9cd8bf29f69'},
#   'createdTime': 1728295926046,
#   'tenantId': {'entityType': 'TENANT',
#    'id': '82737eb0-e429-11e9-ac8f-fdcdec2c26a2'},
#   'customerId': {'entityType': 'CUSTOMER',
#    'id': '13814000-1dd2-11b2-8080-808080808080'},
#   'name': 'Starwis - Keskussairaalantie',
#   'type': 'Starwis',
#   'label': 'Asennettu 20.11.2024',
#   'deviceProfileId': {'entityType': 'DEVICE_PROFILE',
#    'id': 'b017e380-51b8-11eb-9a0e-f36c5aeb7b48'},
#   'firmwareId': None,
#   'softwareId': None,
#   'externalId': None,
#   'additionalInfo': {'gateway': False,
#    'overwriteActivityTime': False,
#    'description': 'RASP0099. Liittymänumero: 040 137 4181, SIM-kortti: 8935801 190354615055'},
#   'ownerId': {'entityType': 'TENANT',
#    'id': '82737eb0-e429-11e9-ac8f-fdcdec2c26a2'},
#   'deviceData': {'configuration': {'type': 'DEFAULT'},
#    'transportConfiguration': {'type': 'DEFAULT'}}},
#  {'id': {'entityType': 'DEVICE', 'id': '9bcb35e0-ff0b-11e9-8fc0-a3372986e528'},
#   'createdTime': 1572876093502,
#   'tenantId': {'entityType': 'TENANT',
#    'id': '82737eb0-e429-11e9-ac8f-fdcdec2c26a2'},
#   'customerId': {'entityType': 'CUSTOMER',
#    'id': '13814000-1dd2-11b2-8080-808080808080'},
#   'name': 'Jyväskylä lentoasema - ID101339',
#   'type': 'FMIWeatherStation',
#   'label': None,
#   'deviceProfileId': {'entityType': 'DEVICE_PROFILE',
#    'id': 'b006a570-51b8-11eb-9a0e-f36c5aeb7b48'},
#   'firmwareId': None,
#   'softwareId': None,
#   'externalId': None,
#   'additionalInfo': None,
#   'ownerId': {'entityType': 'TENANT',
#    'id': '82737eb0-e429-11e9-ac8f-fdcdec2c26a2'},
#   'deviceData': {'configuration': {'type': 'DEFAULT'},
#    'transportConfiguration': {'type': 'DEFAULT'}}},
#  {'id': {'entityType': 'DEVICE', 'id': 'ee2d00a0-9107-11ef-ad64-d9cd8bf29f69'},
#   'createdTime': 1729664871850,
#   'tenantId': {'entityType': 'TENANT',
#    'id': '82737eb0-e429-11e9-ac8f-fdcdec2c26a2'},
#   'customerId': {'entityType': 'CUSTOMER',
#    'id': '13814000-1dd2-11b2-8080-808080808080'},
#   'name': 'LHT65N - Keskussairaalantie (2m)',
#   'type': 'lht65n',
#   'label': 'DevEUI: A84041FD4187A573',
#   'deviceProfileId': {'entityType': 'DEVICE_PROFILE',
#    'id': 'bdf11560-5149-11ee-abaa-4d5079672e6d'},
#   'firmwareId': None,
#   'softwareId': None,
#   'externalId': None,
#   'additionalInfo': {'gateway': False,
#    'overwriteActivityTime': False,
#    'description': 'LHT65N23007\nJyväskylän säätolppa, korkeus 2 metriä\nOletus sijainti: 62.2328107 25.7180178'},
#   'ownerId': {'entityType': 'TENANT',
#    'id': '82737eb0-e429-11e9-ac8f-fdcdec2c26a2'},
#   'deviceData': {'configuration': {'type': 'DEFAULT'},
#    'transportConfiguration': {'type': 'DEFAULT'}}},
#  {'id': {'entityType': 'DEVICE', 'id': 'fb0b38f0-9107-11ef-ad64-d9cd8bf29f69'},
#   'createdTime': 1729664893439,
#   'tenantId': {'entityType': 'TENANT',
#    'id': '82737eb0-e429-11e9-ac8f-fdcdec2c26a2'},
#   'customerId': {'entityType': 'CUSTOMER',
#    'id': '13814000-1dd2-11b2-8080-808080808080'},
#   'name': 'LHT65N - Keskussairaalantie (5m)',
#   'type': 'lht65n',
#   'label': 'DevEUI: A84041F50187A5EB',
#   'deviceProfileId': {'entityType': 'DEVICE_PROFILE',
#    'id': 'bdf11560-5149-11ee-abaa-4d5079672e6d'},
#   'firmwareId': None,
#   'softwareId': None,
#   'externalId': None,
#   'additionalInfo': {'gateway': False,
#    'overwriteActivityTime': False,
#    'description': 'LHT65N23008\nJyväskylän säätolppa, korkeus 5 metriä\nOletus sijainti: 62.2328107 25.7180178'},
#   'ownerId': {'entityType': 'TENANT',
#    'id': '82737eb0-e429-11e9-ac8f-fdcdec2c26a2'},
#   'deviceData': {'configuration': {'type': 'DEFAULT'},
#    'transportConfiguration': {'type': 'DEFAULT'}}}]

# %%
devices = []
for group in device_groups:
    time.sleep(1)
    req_url = f"http://www.infraweb-rws.fi/api/entityGroup/{group}/devices?pageSize=100&page=0"
    response = requests.get(req_url, headers=req_headers)
    data = response.json()
    for entity in data['data']:
        if entity['id']['entityType'] == 'DEVICE':
            devices.append(entity['id']['id'])

# %%
len(devices)
# Out:
# 9

# %%
# test the device id
dev_id = devices[0]

req_url = f"http://www.infraweb-rws.fi/api/device/{dev_id}"

response = requests.get(req_url, headers=req_headers)

data = response.json()

# %%
data
# Out:
# {'id': {'entityType': 'DEVICE', 'id': '16ceea10-f562-11e9-8fc0-a3372986e528'},
#  'createdTime': 1571813724977,
#  'tenantId': {'entityType': 'TENANT',
#   'id': '82737eb0-e429-11e9-ac8f-fdcdec2c26a2'},
#  'customerId': {'entityType': 'CUSTOMER',
#   'id': '13814000-1dd2-11b2-8080-808080808080'},
#  'name': 'Tie 9 Jyväskylä - ID9014',
#  'type': 'DigitrafficWeatherStation',
#  'label': None,
#  'deviceProfileId': {'entityType': 'DEVICE_PROFILE',
#   'id': 'b0021190-51b8-11eb-9a0e-f36c5aeb7b48'},
#  'firmwareId': None,
#  'softwareId': None,
#  'externalId': None,
#  'additionalInfo': None,
#  'ownerId': {'entityType': 'TENANT',
#   'id': '82737eb0-e429-11e9-ac8f-fdcdec2c26a2'},
#  'deviceData': {'configuration': {'type': 'DEFAULT'},
#   'transportConfiguration': {'type': 'DEFAULT'}}}

# %%
req_url = f"http://www.infraweb-rws.fi/api/plugins/telemetry/DEVICE/{dev_id}/values/timeseries"

response = requests.get(req_url, headers=req_headers)

response.json()
# Out:
# {'ANTURIVIKA': [{'ts': 1652953517000, 'value': '0'}],
#  'ASEMAN_STATUS3': [{'ts': 1678263437000, 'value': '1'}],
#  'ASEMAN_STATUS_1': [{'ts': 1685078195000, 'value': '31'}],
#  'ASEMAN_STATUS_2': [{'ts': 1685078195000, 'value': '31'}],
#  'DSC_STATUS': [{'ts': 1678263437000, 'value': '4'}],
#  'DSC_VASTAANOTTIMEN_PUHTAUS': [{'ts': 1678263437000, 'value': '0'}],
#  'ILMANPAINE': [{'ts': 1685078195000, 'value': '1001.6'}],
#  'KASTEPISTE_ERO_ILMA': [{'ts': 1685078195000, 'value': '8.2'}],
#  'LUMEN_SYVYYS': [{'ts': 1685078195000, 'value': '0'}],
#  'PWD_NAK_TILA': [{'ts': 1685078195000, 'value': '201'}],
#  'PWD_STATUS': [{'ts': 1685078195000, 'value': '201'}],
#  'PWD_TILA': [{'ts': 1685078195000, 'value': '4'}],
#  'SADE_TILA': [{'ts': 1685078195000, 'value': '19'}],
#  'VALLITSEVA_SAA': [{'ts': 1685078195000, 'value': '0'}],
#  'airtemperature1': [{'ts': 1740562539000, 'value': '0.9'}],
#  'airtemperature1change': [{'ts': 1740562539000, 'value': '0.1'}],
#  'averagewindspeed': [{'ts': 1685078195000, 'value': '3.4'}],
#  'bright': [{'ts': 1685078195000, 'value': '1'}],
#  'conductivity1': [{'ts': 1685078195000, 'value': '0'}],
#  'conductivity2': [{'ts': 1685078195000, 'value': '0'}],
#  'dewpoint': [{'ts': 1740562539000, 'value': '0.9'}],
#  'dewpointDiff': [{'ts': 1602160800000, 'value': '2.4000000000000004'}],
#  'fiberresponsebig1': [{'ts': 1685078195000, 'value': '0'}],
#  'fiberresponsebig2': [{'ts': 1685078195000, 'value': '0'}],
#  'fiberresponsesmall1': [{'ts': 1685078195000, 'value': '0'}],
#  'fiberresponsesmall2': [{'ts': 1685078195000, 'value': '0'}],
#  'freezingpoint1': [{'ts': 1729015129000, 'value': '-0.2'}],
#  'freezingpoint2': [{'ts': 1685078195000, 'value': '0'}],
#  'friction3': [{'ts': 1740562539000, 'value': '0.68'}],
#  'friction3number': [{'ts': 1678263437000, 'value': '0.82'}],
#  'groundtemperature1': [{'ts': 1685078195000, 'value': '14.3'}],
#  'groundtemperature2': [{'ts': 1685078195000, 'value': '14.1'}],
#  'humidity': [{'ts': 1740562539000, 'value': '100'}],
#  'iceamount3': [{'ts': 1678263437000, 'value': '0'}],
#  'icefrequency1': [{'ts': 1685078195000, 'value': '475'}],
#  'icefrequency2': [{'ts': 1685078195000, 'value': '635'}],
#  'id': [{'ts': 1685078195000, 'value': '9014'}],
#  'lastDayRainSum': [{'ts': 1602229260000, 'value': '3.6'}],
#  'maxwindspeed': [{'ts': 1685078195000, 'value': '7.3'}],
#  'measuredTime': [{'ts': 1740562539000, 'value': '2025-02-26T09:35:39Z'}],
#  'precipitation': [{'ts': 1740562539000, 'value': '1'}],
#  'precipitationintensity': [{'ts': 1740562539000, 'value': '0.38'}],
#  'precipitationsum': [{'ts': 1740562539000, 'value': '2.3'}],
#  'precipitationtype': [{'ts': 1740562539000, 'value': '10'}],
#  'roaddewpointdifference': [{'ts': 1685078195000, 'value': '16'}],
#  'roadsurfaceconditions1': [{'ts': 1685078195000, 'value': '1'}],
#  'roadsurfaceconditions2': [{'ts': 1685078195000, 'value': '1'}],
#  'roadsurfacestate3': [{'ts': 1678263437000, 'value': '1'}],
#  'roadsurfacetemperature1': [{'ts': 1729015129000, 'value': '4.9'}],
#  'roadsurfacetemperature1change': [{'ts': 1729015129000, 'value': '0.1'}],
#  'roadsurfacetemperature2': [{'ts': 1729015129000, 'value': '4.7'}],
#  'roadsurfacetemperature2change': [{'ts': 1729015129000, 'value': '-0.2'}],
#  'safetytemperature1': [{'ts': 1685078195000, 'value': '0'}],
#  'safetytemperature2': [{'ts': 1685078195000, 'value': '0'}],
#  'saltamount1': [{'ts': 1685078195000, 'value': '0'}],
#  'saltamount2': [{'ts': 1685078195000, 'value': '0'}],
#  'saltconcentration1': [{'ts': 1729015129000, 'value': '0.5'}],
#  'saltconcentration2': [{'ts': 1729015129000, 'value': '0'}],
#  'snowamount3': [{'ts': 1736754447000, 'value': '0'}],
#  'sunup': [{'ts': 1685078195000, 'value': '1'}],
#  'surfacemoisture1': [{'ts': 1685078195000, 'value': '0'}],
#  'surfacemoisture2': [{'ts': 1685078195000, 'value': '0'}],
#  'surfacesignal1': [{'ts': 1685078195000, 'value': '0'}],
#  'surfacesignal2': [{'ts': 1685078195000, 'value': '0'}],
#  'temperature': [{'ts': 1740562539000, 'value': '0.9'}],
#  'visibility': [{'ts': 1685078195000, 'value': '20'}],
#  'visibilitymeters': [{'ts': 1685078195000, 'value': '20000'}],
#  'warning1': [{'ts': 1685078195000, 'value': '0'}],
#  'warning2': [{'ts': 1685078195000, 'value': '0'}],
#  'warning3': [{'ts': 1678263437000, 'value': '0'}],
#  'wateramount3': [{'ts': 1678263437000, 'value': '0'}],
#  'winddirection': [{'ts': 1685078195000, 'value': '283'}],
#  'rain10min': [{'ts': 1740562539000, 'value': '0.38'}],
#  'rain1h': [{'ts': 1740560400000, 'value': '0.116666666666666665'}],
#  'roadTemp': [{'ts': 1729015129000, 'value': '4.9'}],
#  'airTemp': [{'ts': 1740562539000, 'value': '0.9'}],
#  'rain24h': [{'ts': 1740562539000, 'value': '2.3'}],
#  'snow24h': [{'ts': 1603335602224, 'value': '0'}],
#  'dewpointDiffSurface': [{'ts': 1740562539000, 'value': 'NULL'}],
#  'dewpointDiffAir': [{'ts': 1740562539000, 'value': '0'}],
#  'RuleNodeState_763ac2c0-1907-11eb-b6df-59566fc79b24': [{'ts': 1740560400000,
#    'value': '{"sum":"0.249999999999999995"}'}],
#  'freezePointDiff': [{'ts': 1729015129000, 'value': '5.1000000000000005'}],
#  'saltConcentration': [{'ts': 1729015129000, 'value': '0'}],
#  'ILMANPAINE_DERIVAATTA': [{'ts': 1685078195000, 'value': '-0.6'}],
#  'KUURAPISTE_ERO_ILMA': [{'ts': 1685078195000, 'value': '8.2'}],
#  'KUURAPISTE_ERO_TIE': [{'ts': 1685078195000, 'value': '16'}],
#  'KUURAPISTE': [{'ts': 1685078195000, 'value': '1.5'}],
#  'VEDEN_MAARA2': [{'ts': 1685078195000, 'value': '0'}],
#  'DSC_STATUS2': [{'ts': 1685078195000, 'value': '0'}],
#  'NÄK_DSC': [{'ts': 1653463065000, 'value': '0'}],
#  'DSC_VASTAANOTTIMEN_PUHTAUS2': [{'ts': 1685078195000, 'value': '0'}],
#  'KITKA2_LUKU': [{'ts': 1685078195000, 'value': '0.82'}],
#  'TIENPINNAN_TILA_OPT2': [{'ts': 1685078195000, 'value': '1'}],
#  'JAAN_MAARA2': [{'ts': 1685078195000, 'value': '0'}],
#  'KITKA2': [{'ts': 1685078195000, 'value': '0.82'}],
#  'TIENPINNAN_TILA_1': [{'ts': 1685078195000, 'value': '1'}],
#  'ILMAN_LÄMPÖTILA_24H_MIN': [{'ts': 1685078195000, 'value': '7'}],
#  'TIENPINNAN_TILA_OPT1': [{'ts': 1678263437000, 'value': '1'}],
#  'VAROITUS2': [{'ts': 1685078195000, 'value': '0'}],
#  'TIENPINNAN_TILA_2': [{'ts': 1685078195000, 'value': '1'}],
#  'ILMAN_LÄMPÖTILA_24H_MAX': [{'ts': 1685078195000, 'value': '15.9'}],
#  'SADESUMMA_EDELLINEN_24H': [{'ts': 1685078195000, 'value': '2.5'}],
#  'LUMEN_MAARA2': [{'ts': 1685078195000, 'value': '0'}],
#  'ASEMAN_STATUS2': [{'ts': 1685078195000, 'value': '1'}],
#  'TIENPINNAN_TILA2': [{'ts': 1685078195000, 'value': '1'}],
#  'Tie1': [{'ts': 1729015129000, 'value': '4.9'}],
#  'DTie1': [{'ts': 1729015129000, 'value': '0.1'}],
#  'Tie2': [{'ts': 1729015129000, 'value': '4.7'}],
#  'DTie2': [{'ts': 1729015129000, 'value': '-0.2'}],
#  'Maa1': [{'ts': 1729015129000, 'value': '6.7'}],
#  'Maa2': [{'ts': 1729015129000, 'value': '6.5'}],
#  'JääPi1': [{'ts': 1729015129000, 'value': '-0.2'}],
#  'JääPi2': [{'ts': 1729015129000, 'value': '0'}],
#  'KTuuli': [{'ts': 1740562539000, 'value': '4'}],
#  'MTuuli': [{'ts': 1740562539000, 'value': '5.2'}],
#  'TSuunt': [{'ts': 1740562539000, 'value': '135'}],
#  'Sade': [{'ts': 1740562539000, 'value': '1'}],
#  'S-Int': [{'ts': 1740562539000, 'value': '0.38'}],
#  'S-Sum': [{'ts': 1740562539000, 'value': '2.3'}],
#  'S-Olom': [{'ts': 1740562539000, 'value': '10'}],
#  'Näk_km': [{'ts': 1740562539000, 'value': '1.91'}],
#  'Keli1': [{'ts': 1740562539000, 'value': '0'}],
#  'Keli2': [{'ts': 1740562539000, 'value': '0'}],
#  'Varo1': [{'ts': 1740562539000, 'value': '0'}],
#  'Varo2': [{'ts': 1740562539000, 'value': '0'}],
#  'Joht1': [{'ts': 1740562539000, 'value': '0'}],
#  'Joht2': [{'ts': 1740562539000, 'value': '0'}],
#  'PSig1': [{'ts': 1740562539000, 'value': '0'}],
#  'PSig2': [{'ts': 1740562539000, 'value': '0'}],
#  'JTaaj1': [{'ts': 1729015129000, 'value': '105'}],
#  'JTaaj2': [{'ts': 1729015129000, 'value': '150'}],
#  'Stat1': [{'ts': 1740562539000, 'value': '0'}],
#  'Stat2': [{'ts': 1740562539000, 'value': '0'}],
#  'S-Tila': [{'ts': 1740562539000, 'value': '16'}],
#  'KosMä1': [{'ts': 1729015129000, 'value': '0.25'}],
#  'KosMä2': [{'ts': 1729015129000, 'value': '0'}],
#  'SuoMä1': [{'ts': 1729015129000, 'value': '0.1'}],
#  'SuoMä2': [{'ts': 1729015129000, 'value': '0'}],
#  'SuoVä1': [{'ts': 1729015129000, 'value': '0.5'}],
#  'SuoVä2': [{'ts': 1729015129000, 'value': '0'}],
#  'TurLä1': [{'ts': 1729015129000, 'value': '0'}],
#  'TurLä2': [{'ts': 1729015129000, 'value': '0'}],
#  'Näky_m': [{'ts': 1740562539000, 'value': '1911'}],
#  'PWDsta': [{'ts': 1740562539000, 'value': '201'}],
#  'PWDtil': [{'ts': 1740562539000, 'value': '4'}],
#  'PWDnäk': [{'ts': 1740562539000, 'value': '201'}],
#  'LumSyv': [{'ts': 1736754447000, 'value': '0'}],
#  'Aurink': [{'ts': 1740562539000, 'value': '1'}],
#  'Valoa?': [{'ts': 1740562539000, 'value': '1'}],
#  'Säätila': [{'ts': 1740562539000, 'value': '61'}],
#  'KVaP1': [{'ts': 1729015129000, 'value': '0.25'}],
#  'KVaP2': [{'ts': 1729015129000, 'value': '0'}],
#  'KVaS1': [{'ts': 1729015129000, 'value': '0'}],
#  'KVaS2': [{'ts': 1729015129000, 'value': '0'}],
#  'TilaO2': [{'ts': 1740562539000, 'value': '3'}],
#  'Tila1': [{'ts': 1740562539000, 'value': '0'}],
#  'Tila2': [{'ts': 1740562539000, 'value': '0'}],
#  'KeliO2': [{'ts': 1740562539000, 'value': '3'}],
#  'VaroO2': [{'ts': 1740562539000, 'value': '0'}],
#  'Kitka2': [{'ts': 1740562539000, 'value': '0.68'}],
#  'VedMä2': [{'ts': 1740562539000, 'value': '0.41'}],
#  'LumMä2': [{'ts': 1740562539000, 'value': '0.01'}],
#  'JääMä2': [{'ts': 1740562539000, 'value': '0.02'}],
#  'StatO2': [{'ts': 1740562539000, 'value': '3'}],
#  'KitkL2': [{'ts': 1740562539000, 'value': '0.68'}],
#  'DSCpu2': [{'ts': 1740562539000, 'value': '0'}],
#  'DSCst2': [{'ts': 1740562539000, 'value': '0'}],
#  'Sad24h': [{'ts': 1740562539000, 'value': '4.3'}],
#  'Ilma': [{'ts': 1740562539000, 'value': '0.9'}],
#  'DIlm': [{'ts': 1740562539000, 'value': '0.1'}],
#  'KastP': [{'ts': 1740562539000, 'value': '0.9'}],
#  'Koste': [{'ts': 1740562539000, 'value': '100'}],
#  'KpEroT': [{'ts': 1729015129000, 'value': '2.1'}],
#  'KpEroI': [{'ts': 1740562539000, 'value': '0'}],
#  'KuuraP': [{'ts': 1740562539000, 'value': '0.9'}],
#  'KupErT': [{'ts': 1729015129000, 'value': '2.1'}],
#  'KupErI': [{'ts': 1740562539000, 'value': '0'}],
#  'IlmMIN': [{'ts': 1740562539000, 'value': '0.2'}],
#  'IlmMAX': [{'ts': 1740562539000, 'value': '2.3'}],
#  'IPaine': [{'ts': 1740562539000, 'value': '1000.7'}],
#  'DIPain': [{'ts': 1740562539000, 'value': '0.6'}],
#  'PWDrbc': [{'ts': 1740562539000, 'value': '28'}],
#  'PWDtbc': [{'ts': 1740562539000, 'value': '0.33'}],
#  'KpEroT1': [{'ts': 1721126157000, 'value': '17.5'}],
#  'KpEroT2': [{'ts': 1729015129000, 'value': '1.9'}]}
